# %%
import numpy as np
import pandas as pd
import  matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.datasets import load_diabetes

# %%
data=load_diabetes()

# %%
data
# Out:
# {'data': array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#           0.01990749, -0.01764613],
#         [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#          -0.06833155, -0.09220405],
#         [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#           0.00286131, -0.02593034],
#         ...,
#         [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#          -0.04688253,  0.01549073],
#         [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#           0.04452873, -0.02593034],
#         [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#          -0.00422151,  0.00306441]]),
#  'target': array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#          69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#          68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#          87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
# ...

# %%
print(data['DESCR'])
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
# :Number of Instances: 442
#
# :Number of Attributes: First 10 columns are numeric predictive values
#
# :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
# :Attribute Information:
#     - age     age in years
#     - sex
#     - bmi     body mass index
#     - bp      average blood pressure
#     - s1      tc, total serum cholesterol
#     - s2      ldl, low-density lipoproteins
#     - s3      hdl, high-density lipoproteins
#     - s4      tch, total cholesterol / HDL
#     - s5      ltg, possibly log of serum triglycerides level
# ...

# %%
x=pd.DataFrame(data['data'],columns=['age','sex','bmi','bp','total serum cholesterol',
'low-density lipoproteins','high-density lipoproteins','total cholesterol / HDL','possibly log of serum triglycerides level','blood sugar level'])

# %%
x.head()
# Out:
#         age       sex       bmi        bp  total serum cholesterol  \
# 0  0.038076  0.050680  0.061696  0.021872                -0.044223
# 1 -0.001882 -0.044642 -0.051474 -0.026328                -0.008449
# 2  0.085299  0.050680  0.044451 -0.005670                -0.045599
# 3 -0.089063 -0.044642 -0.011595 -0.036656                 0.012191
# 4  0.005383 -0.044642 -0.036385  0.021872                 0.003935
#
#    low-density lipoproteins  high-density lipoproteins  \
# 0                 -0.034821                  -0.043401
# 1                 -0.019163                   0.074412
# 2                 -0.034194                  -0.032356
# 3                  0.024991                  -0.036038
# 4                  0.015596                   0.008142
#
#    total cholesterol / HDL  possibly log of serum triglycerides level  \
# 0                -0.002592                                   0.019907
# 1                -0.039493                                  -0.068332
# ...

# %%
y=data['target']

# %%
y
# Out:
# array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#        259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#        128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#        150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#        200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#         42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#         83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#        104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#        173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#        107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
corr=x_train.corr()

# %%
import seaborn as sns
plt.figure(figsize=(10,11))
sns.heatmap(data=corr,annot=True)
plt.show()

# %%
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()

# %%
param_grid={
    'criterion':['squared_error','absolute_error','poisson'],
    'splitter':['best','random'],
     'max_depth':[1,2,3,4,5,10,15,20,25],
     'min_samples_split':[2,3,4,5,6,7],
    'max_features':['sqrt','log2']
}

# %%
from sklearn.model_selection import StratifiedKFold
cv=StratifiedKFold()

# %%
from sklearn.model_selection import GridSearchCV
grid=GridSearchCV(estimator=dtr,param_grid=param_grid,cv=cv,n_jobs=-1,scoring='accuracy')

# %%
import warnings
warnings.filterwarnings('ignore')
grid.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=False),
#              estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'poisson'],
#                          'max_depth': [1, 2, 3, 4, 5, 10, 15, 20, 25],
#                          'max_features': ['sqrt', 'log2'],
#                          'min_samples_split': [2, 3, 4, 5, 6, 7],
#                          'splitter': ['best', 'random']},
#              scoring='accuracy')

# %%
grid.best_params_
# Out:
# {'criterion': 'poisson',
#  'max_depth': 25,
#  'max_features': 'sqrt',
#  'min_samples_split': 2,
#  'splitter': 'random'}

# %%
grid.best_score_
# Out:
# np.float64(0.01694164989939638)

# %%
y_pred=grid.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
R2_score=r2_score(y_test,y_pred)
print(f"mean_squared_error:{mse}")
print(f"mean_absolute_error:{mae}")
print(f"R^2 Score:{R2_score}")
# Out:
# mean_squared_error:6694.887640449439
# mean_absolute_error:68.41573033707866
# R^2 Score:-0.2636270077247034

# %%
new_data=[[-0.0088231,-0.045242,-0.061474,0.029548,-0.0095469,-0.016193,0.074699,-0.034433,-0.078972,-0.072705]]

# %%
print(grid.predict(new_data))
# Out:
# [96.]

# %%
model=DecisionTreeRegressor(criterion='poisson',
 max_depth=25,
 max_features='sqrt',
 min_samples_split= 2,
 splitter='random')

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='poisson', max_depth=25, max_features='sqrt',
#                       splitter='random')

# %%
from sklearn import tree
plt.figure(figsize=(10,11))
tree.plot_tree(model9,filled=True)
plt.show()
